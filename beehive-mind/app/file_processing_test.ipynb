# %%
from pathlib import Path

from pydub import AudioSegment
from pydub.utils import db_to_float
from pydub.utils import mediainfo

input_path = Path('./data/audio_input')
output_path = Path('./data/audio_output')
unique_extensions = set()

# %%
for file in input_path.rglob('*'):  # Recursively iterates through all files in subdirectories
    if file.is_file():
        unique_extensions.add(file.suffix)

print(unique_extensions)  # Outputs a set of unique file extensions
# Out:
# {'.wav', '.mp3'}

# %%
durations = []

for file in input_path.rglob('*'):
    if file.is_file() and file.suffix in {'.wav', '.mp3'}:
        info = mediainfo(str(file))
        duration = float(info['duration'])
        durations.append(duration)

if durations:
    print(f"Max length: {max(durations)} seconds")
    print(f"Min length: {min(durations)} seconds")
else:
    print("No audio files found.")
# Out:
# /home/carlos/Documents/ITH/Tesis/ai/scientificProject/.venv/lib/python3.12/site-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /home/carlos/Documents/ITH/Tesis/ai/scientificProject/.venv/lib/python3.12/site-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /home/carlos/Documents/ITH/Tesis/ai/scientificProject/.venv/lib/python3.12/site-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /home/carlos/Documents/ITH/Tesis/ai/scientificProject/.venv/lib/python3.12/site-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 for file in input_path.rglob('*'):
#       4     if file.is_file() and file.suffix in {'.wav', '.mp3'}:
# ----> 5         info = mediainfo(str(file))
#       6         duration = float(info['duration'])
#       7         durations.append(duration)
#
# File ~/Documents/ITH/Tesis/ai/scientificProject/.venv/lib/python3.12/site-packages/pydub/utils.py:335, in mediainfo(filepath)
#     333 command = [prober, '-of', 'old'] + command_args
#     334 res = Popen(command, stdout=PIPE)
# --> 335 output = res.communicate()[0].decode("utf-8")
#     337 if res.returncode != 0:
#     338     command = [prober] + command_args
#
# File /usr/lib/python3.12/subprocess.py:1196, in Popen.communicate(self, input, timeout)
#    1194     self._stdin_write(input)
#    1195 elif self.stdout:
# -> 1196     stdout = self.stdout.read()
#    1197     self.stdout.close()
#    1198 elif self.stderr:
#
# KeyboardInterrupt:

# %%
def split_audio(input_folder, output_folder, segment_length=2000, min_amplitude_db=-30):
    input_folder_path = Path(input_folder)
    output_folder_path = Path(output_folder)
    min_amplitude = db_to_float(min_amplitude_db)

    for file in input_folder_path.rglob('*'):
        if file.is_file() and file.suffix.lower() in {'.wav', '.mp3'}:
            try:
                # Determine the relative path of the file from the input folder
                relative_path = file.relative_to(input_folder_path)

                # Create the corresponding output subfolder
                output_subfolder = output_folder_path / relative_path.parent
                output_subfolder.mkdir(parents=True, exist_ok=True)

                audio = AudioSegment.from_file(str(file), format=file.suffix.lower()[1:])

                for i, chunk in enumerate(audio[::segment_length]):
                    # Check if the maximum amplitude of the chunk is above the threshold
                    if chunk.max_dBFS > min_amplitude_db:
                        output_file = output_subfolder / f"{file.stem}_{i}{file.suffix}"
                        chunk.export(output_file, format=file.suffix.lower()[1:])
                        print(f"Exported: {output_file}")
                    else:
                        print(f"Skipped chunk {i} from {relative_path} (below amplitude threshold)")

                print(f"Processed: {relative_path}")
            except Exception as e:
                print(f"Error processing {file}: {str(e)}")
    print("Finished")


segment_length = 2000  # 2 seconds
min_amplitude_db = -30  # Minimum amplitude threshold in dB
split_audio(input_path, output_path, segment_length, min_amplitude_db)
# Out:
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-24-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-22-4-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-14-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-30-14-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-2-14-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-86-12.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-10-25-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-2-28-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-0.wav
# Processed: Active/CF003 - Active - Day - (221)-0-46.wav
# Processed: Active/#DH001 - Active - Normal - 10000 Bees.mp3
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-10-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-16-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (218)-2-54.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-26.wav
# Processed: Active/CF003 - Active - Day - (217)-20-19.wav
# Processed: Active/CF003 - Active - Day - (227)-10-27.wav
# Processed: Active/CF003 - Active - Day - (224)-2-35.wav
# Processed: Active/CF003 - Active - Day - (216)-2-75.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-50-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-10-15-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-59-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-20-5-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-4-6-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-119.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-20-38-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-14-13-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-12-12-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-8-14.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-0-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-4-19-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-8-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-73.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-6-3.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-94-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-21.wav
# Processed: Active/CF003 - Active - Day - (216)-2-115.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-4-10-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-26-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-68-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-84.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-12-12-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-12-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-4-26-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-86-5.wav
# Processed: Active/CF003_269_a.wav
# Processed: Active/CF003 - Active - Day - (226)-2-83.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-10-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-14-21-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-66.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-16-1-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-12.wav
# Processed: Active/CF003 - Active - Day - (224)-0-27.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-20-6.wav
# Processed: Active/CF003 - Active - Day - (217)-30-5.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-21-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-8-11-upsampled.wav
# Processed: Active/CF003 - Active - Day - (224)-0-69.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-26-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-18-11-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-20-15.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-4-6-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-6-27-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-90.wav
# Processed: Active/CF003 - Active - Day - (218)-2-19.wav
# Processed: Active/CF003 - Active - Day - (223)-2-135.wav
# Processed: Active/CF003_63_a.wav
# Processed: Active/CF003 - Active - Day - (226)-2-60.wav
# Processed: Active/CF003 - Active - Day - (216)-2-96.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-30-30-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-16-29-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-78.wav
# Processed: Active/CF003 - Active - Day - (217)-14-2.wav
# Processed: Active/CF003 - Active - Day - (223)-2-62.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-8-1-upsampled.wav
# Processed: Active/CF003 - Active - Day - (227)-4-56.wav
# Processed: Active/CF003 - Active - Day - (217)-20-0.wav
# Processed: Active/CF003 - Active - Day - (223)-2-33.wav
# Processed: Active/CF003 - Active - Day - (224)-0-33.wav
# Processed: Active/CF003 - Active - Day - (221)-0-17.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-4-2.wav
# Processed: Active/CF003 - Active - Day - (225)-0-134.wav
# Processed: Active/CF003 - Active - Day - (220)-0-81.wav
# Processed: Active/CF003 - Active - Day - (215)-0-4.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-26-2-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-84-7.wav
# Processed: Active/CF003_214_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-0-8-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-15-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-26-0-upsampled.wav
# Processed: Active/CF003_54_a.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-29.wav
# Processed: Active/CF003 - Active - Day - (218)-8-15.wav
# Processed: Active/CF003_180_a.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-26-4.wav
# Processed: Active/CF003 - Active - Day - (225)-0-138.wav
# Processed: Active/CF003 - Active - Day - (224)-2-16.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-10-11-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-47-upsampled.wav
# Processed: Active/CF003 - Active - Day - (224)-2-2.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-14-8.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-20-39-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-30-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-4-0-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-125.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-20-8.wav
# Processed: Active/CF003 - Active - Day - (219)-56-1.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-12-4.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-88-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-10-8-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-90.wav
# Processed: Active/CF003_229_a.wav
# Processed: Active/CF003 - Active - Day - (215)-26-17.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-8-4-upsampled.wav
# Processed: Active/CF003_233_a.wav
# Processed: Active/CF003 - Active - Day - (225)-0-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-16-28-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-2-27-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-4-4-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-42-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-16-34-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-18-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-6.wav
# Processed: Active/CF003 - Active - Day - (224)-0-75.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-14-11-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-12-8.wav
# Processed: Active/CF003_11_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-4-24-upsampled.wav
# Processed: Active/CF003 - Active - Day - (215)-26-26.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-25.wav
# Processed: Active/CF003 - Active - Day - (214)-4-1.wav
# Processed: Active/CF003 - Active - Day - (218)-8-21.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-4-63-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-30-19-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-14-0-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-49.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-43-upsampled.wav
# Processed: Active/CF003 - Active - Day - (215)-26-9.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-33.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-72-11.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-42-4.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-2-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-10-0-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-16-14-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-10-30-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-20-0-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-2-3-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-6-16-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-12-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-20-65-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-4-3-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-6-22-upsampled.wav
# Processed: Active/CF003_197_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-28-7-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-2-13-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-23-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-8-1-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-105.wav
# Processed: Active/CF003 - Active - Day - (221)-0-71.wav
# Processed: Active/CF003 - Active - Day - (219)-56-3.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-80.wav
# Processed: Active/CF003 - Active - Day - (227)-4-49.wav
# Processed: Active/CF003 - Active - Day - (215)-24-5.wav
# Processed: Active/CF003 - Active - Day - (224)-0-46.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-10-9-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-20-4.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-26-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-6-26-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-8-18-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-8-9-upsampled.wav
# Processed: Active/CF003 - Active - Day - (224)-2-11.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-2-10-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-119.wav
# Processed: Active/CF003 - Active - Day - (220)-0-30.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-10-9-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-66-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-30-2-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-12.wav
# Processed: Active/CF003_230_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-30-upsampled.wav
# Processed: Active/CF003 - Active - Day - (226)-2-82.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-30-31-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-16-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-32.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-10-0-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-134.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-20-3-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-20-15.wav
# Processed: Active/CF003 - Active - Day - (220)-0-4.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-24-31-upsampled.wav
# Processed: Active/CF003 - Active - Day - (218)-2-60.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-0-4-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-126-0.wav
# Processed: Active/CF003 - Active - Day - (218)-2-61.wav
# Processed: Active/CF003_21_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-24-23-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-10-10-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-10-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-36.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-20-12-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-24-23-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-11-upsampled.wav
# Processed: Active/CF003 - Active - Day - (215)-16-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-8-7-upsampled.wav
# Processed: Active/CF003 - Active - Day - (221)-0-56.wav
# Processed: Active/CF003 - Active - Day - (227)-8-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-16-10-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-6-11-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (225)-0-114.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-4-35-upsampled.wav
# Processed: Active/CF003_216_a.wav
# Processed: Active/CF003 - Active - Day - (218)-2-55.wav
# Processed: Active/CF003 - Active - Day - (222)-0-54.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-28-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-10-3-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-34-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-15-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-20-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-8-37-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-84-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-2-29-upsampled.wav
# Processed: Active/CF003 - Active - Day - (214)-14-2.wav
# Processed: Active/CF003 - Active - Day - (226)-2-56.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-33-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-72-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-49-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-12-10-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-30-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-62-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-4-5-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-20-14-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-0-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-56.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-16-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-4-0-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-10-8-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-20-0.wav
# Processed: Active/CF003 - Active - Day - (226)-2-62.wav
# Processed: Active/CF003_223_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-40-1-upsampled.wav
# Processed: Active/CF003 - Active - Day - (215)-26-14.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-12-4.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-90-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-4-7-upsampled.wav
# Processed: Active/CF003_246_a.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-6-4.wav
# Processed: Active/CF003 - Active - Day - (223)-0-0.wav
# Processed: Active/CF003 - Active - Day - (218)-0-19.wav
# Processed: Active/CF003 - Active - Day - (217)-30-2.wav
# Processed: Active/CF003 - Active - Day - (225)-0-96.wav
# Processed: Active/CF003 - Active - Day - (220)-0-82.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-26-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-16-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-43-upsampled.wav
# Processed: Active/CF003_260_a.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-8-14.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-8-20-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-22-1-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-84-13.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-24.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-2-32-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-30-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (218)-8-17.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-24-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-22-5-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-18-9-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-36-3-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-80.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-4-0.wav
# Processed: Active/CF003 - Active - Day - (225)-0-46.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-16-5-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-90-3.wav
# Processed: Active/CF003 - Active - Day - (224)-0-55.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-22-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-93.wav
# Processed: Active/CF003 - Active - Day - (218)-2-18.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-34-6-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-18-1-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-114.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-68.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-31-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-88-15.wav
# Processed: Active/CF003 - Active - Day - (214)-14-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-0-22.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-26-12.wav
# Processed: Active/CF003 - Active - Day - (219)-2-2.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-86-28.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (224)-0-28.wav
# Processed: Active/CF003 - Active - Day - (216)-2-16.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-14-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-24-1-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-22-3.wav
# Processed: Active/CF003_300_a.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-9.wav
# Processed: Active/CF003 - Active - Day - (220)-0-40.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-21-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-26-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-14-15-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-0-0.wav
# Processed: Active/CF003 - Active - Day - (218)-2-33.wav
# Processed: Active/CF003 - Active - Day - (225)-0-66.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-2-6-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-4-0-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-12-1.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-18-8.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-6-4-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-22-4-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-10-1.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-12-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-2-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-18-20-upsampled.wav
# Processed: Active/CF003 - Active - Day - (219)-24-2.wav
# Processed: Active/CF003 - Active - Day - (226)-0-21.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-8-3-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-18-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-2-13-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-18-4.wav
# Processed: Active/CF003_94_a.wav
# Processed: Active/CF003 - Active - Day - (227)-8-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-39.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-13.wav
# Processed: Active/CF003 - Active - Day - (220)-0-38.wav
# Processed: Active/CF003 - Active - Day - (216)-2-44.wav
# Processed: Active/CF003 - Active - Day - (225)-0-83.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-28-8-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-24-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-18-upsampled.wav
# Processed: Active/CF003 - Active - Day - (218)-8-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-20-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-69-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-22-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-32-9-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-58-1.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-5.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-41.wav
# Processed: Active/CF003 - Active - Day - (227)-4-48.wav
# Processed: Active/CF003 - Active - Day - (224)-0-51.wav
# Processed: Active/CF003_297_a.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-136-0.wav
# Processed: Active/CF003 - Active - Day - (219)-20-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-11-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-26-7-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-18.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-13-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-6-7.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-2-0.wav
# Processed: Active/CF003 - Active - Day - (221)-0-66.wav
# Processed: Active/CF003 - Active - Day - (215)-20-7.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-0-13-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-6-10-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-16-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (219)-6-3.wav
# Processed: Active/CF003 - Active - Day - (218)-8-24.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-10.wav
# Processed: Active/CF003 - Active - Day - (226)-2-90.wav
# Processed: Active/CF003 - Active - Day - (220)-0-144.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-4-10-upsampled.wav
# Processed: Active/CF003 - Active - Day - (225)-0-19.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-27-upsampled.wav
# Processed: Active/CF003 - Active - Day - (224)-0-13.wav
# Processed: Active/CF003 - Active - Day - (218)-0-11.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-4-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-117.wav
# Processed: Active/CF003 - Active - Day - (215)-0-5.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-14-5.wav
# Processed: Active/CF003 - Active - Day - (225)-0-111.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-20-50-upsampled.wav
# Processed: Active/CF003 - Active - Day - (218)-0-15.wav
# Processed: Active/CF003 - Active - Day - (227)-10-2.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-74.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-22-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-24-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (218)-2-3.wav
# Processed: Active/CF003 - Active - Day - (221)-2-17.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-16-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-14-8-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-30-8-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-2-0-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-4-1.wav
# Processed: Active/CF003 - Active - Day - (222)-0-11.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-68.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-7.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-12-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-4.wav
# Processed: Active/CF003 - Active - Day - (225)-0-136.wav
# Processed: Active/CF003 - Active - Day - (227)-10-20.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-24-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-37.wav
# Processed: Active/CF003_279_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-8-38-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-20.wav
# Processed: Active/CF003 - Active - Day - (226)-2-99.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-26-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-10-11-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-18-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-4-10-upsampled.wav
# Processed: Active/CF003 - Active - Day - (227)-4-38.wav
# Processed: Active/CF003 - Active - Day - (226)-2-109.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-14-12-upsampled.wav
# Processed: Active/CF003 - Active - Day - (227)-0-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-18-14-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-30-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (215)-22-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-28-7-upsampled.wav
# Processed: Active/CF003 - Active - Day - (221)-0-21.wav
# Processed: Active/CF003 - Active - Day - (216)-2-30.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-16-7-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-45.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-23.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-2-7-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-20-1.wav
# Processed: Active/CF003_166_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-6-25-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-10-5-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-24-34-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-4-24-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-26-12-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-59-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-64.wav
# Processed: Active/CF003 - Active - Day - (227)-4-54.wav
# Processed: Active/CF003 - Active - Day - (222)-0-64.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-14-6-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-8-3-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-26.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-76-4.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-16-10.wav
# Processed: Active/CF003 - Active - Day - (224)-0-47.wav
# Processed: Active/CF003 - Active - Day - (215)-4-10.wav
# Processed: Active/CF003_155_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-12-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-88-14.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-67-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-30-0-upsampled.wav
# Processed: Active/CF003 - Active - Day - (225)-0-76.wav
# Processed: Active/CF003 - Active - Day - (222)-0-132.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-20-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-69.wav
# Processed: Active/CF003 - Active - Day - (220)-0-143.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-94-1.wav
# Processed: Active/CF003 - Active - Day - (218)-0-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-26-31-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-102-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-16-14-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-28-7.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-32-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-48-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-78.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-20-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-2-36-upsampled.wav
# Processed: Active/CF003 - Active - Day - (226)-2-85.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-42-4-upsampled.wav
# Processed: Active/CF003_253_a.wav
# Processed: Active/CF003 - Active - Day - (226)-2-27.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-10-21-upsampled.wav
# Processed: Active/CF003 - Active - Day - (226)-0-25.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-16-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-82.wav
# Processed: Active/CF003_285_a.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-83.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-14-4-upsampled.wav
# Processed: Active/CF003_25_a.wav
# Processed: Active/CF003_19_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-10-2-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-6-12.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-40-13.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-30-11-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-2-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-103.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-12-14.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-90-2.wav
# Processed: Active/CF003 - Active - Day - (222)-0-51.wav
# Processed: Active/CF003 - Active - Day - (217)-14-1.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-16-12-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-56.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-22-8-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-16-9-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-20-upsampled.wav
# Processed: Active/CF003 - Active - Day - (216)-2-59.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-0-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-39-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-10-3-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-70-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-10-29-upsampled.wav
# Processed: Active/CF003_158_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-16-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-28-1-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-8-19.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-10-14-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-8-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-19.wav
# Processed: Active/CF003 - Active - Day - (226)-2-65.wav
# Processed: Active/CF003_112_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-30-1-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-146-1.wav
# Processed: Active/CF003 - Active - Day - (224)-0-70.wav
# Processed: Active/CF003 - Active - Day - (227)-0-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-26-17-upsampled.wav
# Processed: Active/CF003 - Active - Day - (214)-6-0.wav
# Processed: Active/CF003 - Active - Day - (225)-0-144.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-73-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-38-13-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-10-19-upsampled.wav
# Processed: Active/CF003 - Active - Day - (221)-0-18.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-10-7-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-106.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-10-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-26-37-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-86-13.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-30-7.wav
# Processed: Active/CF003 - Active - Day - (220)-0-53.wav
# Processed: Active/CF003 - Active - Day - (225)-0-139.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-25-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-77.wav
# Processed: Active/CF003 - Active - Day - (220)-0-88.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-20-16.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-50-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-22-5-upsampled.wav
# Processed: Active/CF003_185_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-10-23-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-28-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-11-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-16-4-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-67-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-30-7.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-4-21-upsampled.wav
# Processed: Active/CF003 - Active - Day - (221)-2-59.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-72-21.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-12-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-18-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-121.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-86-27.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-12-1-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-16-15.wav
# Processed: Active/CF003 - Active - Day - (217)-20-16.wav
# Processed: Active/CF003_156_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-14-10-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-55-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-0-16-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-10-8-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-42.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-88.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-16-14-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-6-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-4-2-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-14-9.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-14-28-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-88-5.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-8-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-26-4-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-37-upsampled.wav
# Processed: Active/CF003 - Active - Day - (219)-24-7.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-78-6.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-22-6-upsampled.wav
# Processed: Active/CF003_41_a.wav
# Processed: Active/CF003 - Active - Day - (219)-36-1.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-86-4.wav
# Processed: Active/CF003 - Active - Day - (218)-2-47.wav
# Processed: Active/CF003 - Active - Day - (219)-68-3.wav
# Processed: Active/CF003 - Active - Day - (220)-0-52.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-33.wav
# Processed: Active/CF003 - Active - Day - (215)-24-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-24-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-44.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-20-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-10-26-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-12-59-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-26-10-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-89.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-18-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-84-4.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-99.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-86-7.wav
# Processed: Active/CF003 - Active - Day - (220)-0-120.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-14-6-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-88.wav
# Processed: Active/CF003 - Active - Day - (227)-4-26.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-26-6-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-6-0-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-22-21-upsampled.wav
# Processed: Active/CF003 - Active - Day - (219)-6-0.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-8-6.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-84-9.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-6-29-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-34-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (219)-22-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-82-50.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-4-25-upsampled.wav
# Processed: Active/CF003 - Active - Day - (227)-4-43.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-20-6-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-4-23-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-113.wav
# Processed: Active/CF003 - Active - Day - (217)-8-15.wav
# Processed: Active/CF003 - Active - Day - (224)-0-6.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-10-2-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_30_00-6-18-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-47.wav
# Processed: Active/CF003 - Active - Day - (221)-0-70.wav
# Processed: Active/CF003 - Active - Day - (221)-0-72.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-30-2.wav
# Processed: Active/CF003 - Active - Day - (223)-2-48.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-16-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (223)-2-92.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-0-19-upsampled.wav
# Processed: Active/CF003 - Active - Day - (225)-0-108.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-20-9.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-18-7.wav
# Processed: Active/CF003 - Active - Day - (222)-0-101.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-22-24-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-34-0.wav
# Processed: Active/CF003 - Active - Day - (221)-0-5.wav
# Processed: Active/CF003 - Active - Day - (218)-0-4.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-20-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-38-5-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-27.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-2-4-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-37.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-0-21.wav
# Processed: Active/CF003 - Active - Day - (219)-20-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___17_00_00-8-41-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_10_00-24-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (220)-0-100.wav
# Processed: Active/CF003 - Active - Day - (223)-2-13.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-8-6-upsampled.wav
# Processed: Active/CF003 - Active - Day - (224)-2-47.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-0-4-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-16.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-14-6-upsampled.wav
# Processed: Active/CF003 - Active - Day - (224)-2-4.wav
# Processed: Active/CF003 - Active - Day - (222)-0-138.wav
# Processed: Active/CF003 - Active - Day - (218)-12-9.wav
# Processed: Active/CF003 - Active - Day - (225)-0-145.wav
# Processed: Active/CF003 - Active - Day - (227)-10-31.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-53.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-10-12-upsampled.wav
# Processed: Active/CF003 - Active - Day - (219)-16-5.wav
# Processed: Active/CF003 - Active - Day - (222)-0-114.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-14-13-upsampled.wav
# Processed: Active/CF003 - Active - Day - (222)-0-118.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-20-11.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-14-27-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-26-5.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-16-27.wav
# Processed: Active/CF003 - Active - Day - (223)-2-29.wav
# Processed: Active/CF003 - Active - Day - (220)-0-29.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-38-2-upsampled.wav
# Processed: Active/CF003 - Active - Day - (215)-26-5.wav
# Processed: Active/CF003 - Active - Day - (222)-0-30.wav
# Processed: Active/CF003 - Active - Day - (216)-4-4.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-14-29-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-8-9-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-0-54-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-4-0-upsampled.wav
# Processed: Active/CF003 - Active - Day - (225)-0-50.wav
# Processed: Active/CF003 - Active - Day - (218)-2-29.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_40_00-16-47-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_00_00-4-1-upsampled.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-4-0.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_10_00-18-3.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_50_00-12-51-upsampled.wav
# Processed: Active/CF003_234_a.wav
# Processed: Active/CF003_284_a.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-10-8-upsampled.wav
# Processed: Active/CF003 - Active - Day - (227)-4-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-26-11-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-44-0.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-0-13.wav
# Processed: Active/CF003 - Active - Day - (218)-2-7.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_20_00-4-8-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-8-0-upsampled.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-80-2.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_00_00-8-25-upsampled.wav
# Processed: Active/CF003_87_a.wav
# Processed: Active/CF003 - Active - Day - (222)-0-57.wav
# Processed: Active/CF003 - Active - Day - (224)-0-20.wav
# Processed: Active/CF003_111_a.wav
# Processed: Active/Hive3_20_07_2017_QueenBee_H3_audio___06_20_00-18-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_30_00-50-3-upsampled.wav
# Processed: Active/CF003 - Active - Day - (217)-20-8.wav
# Processed: Active/CF003 - Active - Day - (223)-2-127.wav
# Processed: Active/CF003 - Active - Day - (215)-26-18.wav
# Processed: Active/GH001 - Active - Day - 141022_0659_0751-22-100.wav
# Processed: Active/CF003 - Active - Day - (225)-0-22.wav
# Processed: Active/CF003 - Active - Day - (219)-56-2.wav
# Processed: Active/CF003 - Active - Day - (219)-68-0.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___16_40_00-2-1-upsampled.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_10_00-20-76-upsampled.wav
# Processed: Active/CF003 - Active - Day - (225)-0-69.wav
# Processed: Active/Hive1_12_06_2018_QueenBee_H1_audio___15_20_00-8-11-upsampled.wav
# ...
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_50_00-30-2.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_10_00-10-9-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_30_00-62-2-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-16-3-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_10_00-10-7-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-0-9.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-16-18.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-28-0.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_10_00-2-1-upsampled.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (102)-10-6.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___17_00_00-20-0.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-32-11.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___17_00_00-12-13.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (103)-70-0.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-10-18.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-12-5.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-18-5.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-14-1.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___17_00_00-16-6.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-2-9.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-20-18.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_30_00-12-7-upsampled.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (101)-0-19.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_00_00-32-16.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-10-12.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-20-16.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-18-11-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-32-10.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-16-0.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-4-11.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_10_00-18-6-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-10-2-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-0-69.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-20-14.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-30-5.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-2-7.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-6-88.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_00_00-14-6.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_30_00-80-4-upsampled.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (101)-32-5.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-34-9.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_20_00-2-20.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-10-15.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-8-23-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-6-26.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-22-14.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-6-3.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-0-32.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___17_00_00-0-4.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-14-5.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_30_00-60-1-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-6-4-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-4-0.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-12-36.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_20_00-22-5.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_30_00-2-2-upsampled.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (100)-16-1.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-8-1.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_10_00-14-4.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-74-3-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-22-70.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___17_00_00-16-8.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-0-27.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-8-39-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-24-31.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-0-37.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (100)-8-2.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-6-59.wav
# Processed: Missing Queen/CF001 - Missing Queen - Day --2-0.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_10_00-20-2.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-18-0.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-22-11.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_10_00-20-10.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-22-0.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (102)-10-10.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-40-40.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-0-39.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-6-115.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-2-9.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-14-5.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___17_00_00-12-15.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-6-27.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-82-0-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-40-1-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-18-13.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-16-22-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_00_00-30-19.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (100)-2-2.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_10_00-18-5-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-10-26.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-40-8.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-12-2.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-12-22.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-10-3.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (102)-0-1.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_50_00-6-16.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-78-3-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-40-4.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-22-1.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-0-35.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_30_00-34-0-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-0-15.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-16-16.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-12-49.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-32-6.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-4-32.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-0-2.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_30_00-62-1-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-24-0-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-8-44-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-4-1.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-28-6.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-4-21.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-0-50-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-0-81.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-8-35-upsampled.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (103)-62-1.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-12-65.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-12-61.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-10-2.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-10-0.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-38-6.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-0-31.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-6-2.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-16-13.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-6-49.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-26-3.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-10-16.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-0-77.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-12-48.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-12-7.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_00_00-36-1.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-0-3.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-30-12.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-18-3.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_50_00-12-10.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_50_00-40-17.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-0-80.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_40_00-16-3.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-30-0.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-20-7.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-26-10-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-0-42.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-20-2-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-10-0-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_20_00-10-12.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_40_00-118-0-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_50_00-16-22.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_30_00-20-9.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-0-1.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-0-15.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-18-7-upsampled.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (102)-12-40.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-66-2-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_10_00-12-12-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-0-12.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-32-3.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_00_00-4-24.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_40_00-8-14.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-8-22-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-38-10.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-12-5.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_00_00-84-11-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_20_00-0-25.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-2-19.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_30_00-0-48.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_40_00-8-1-upsampled.wav
# Processed: Missing Queen/CJ001 - Missing Queen - Day -  (102)-6-5.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_20_00-4-0.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_20_00-8-5.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___17_00_00-0-0.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_00_00-32-5.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_10_00-28-8-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_10_00-0-16.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-26-23-upsampled.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-18-1-upsampled.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-2-14.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-4-14.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_20_00-6-10.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___07_00_00-22-76.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_20_00-16-21-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-14-10.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_50_00-30-7.wav
# Processed: Missing Queen/Hive1_31_05_2018_NO_QueenBee_H1_audio___15_40_00-100-0-upsampled.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_40_00-30-12.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___15_10_00-18-6.wav
# Processed: Missing Queen/Hive3_12_07_2017_NO_QueenBee_H3_audio___16_50_00-16-1.wav
# Processed: Missing Queen/Hive3_15_07_2017_NO_QueenBee_H3_audio___06_30_00-8-30.wav
# Processed: Queen Hatching/#CF001 - Queen Hatching - Day.mp3
# Processed: Pre-Swarm/#TW001 - Pre-Swarm - Day.mp3

# %%
def reduce_noise_stft(audio_segment: AudioSegment, noise, noise_reduction_factor: float = 0.5):
    # Convert to numpy array and normalize
    samples = np.array(audio_segment.get_array_of_samples()).astype(np.float32)
    samples /= np.max(np.abs(samples))  # Normalize to [-1, 1]

    noise_samples = np.array(noise.get_array_of_samples()).astype(np.float32)
    # noise_samples /= np.max(np.abs(samples))

    # Define STFT parameters
    fs = audio_segment.frame_rate
    nperseg = 1024  # Larger value = better frequency resolution, less temporal resolution
    noverlap = nperseg // 2  # 50% overlap
    window = 'hann'

    # Perform STFT
    f, t, Zxx = stft(samples, fs=fs, nperseg=nperseg, noverlap=noverlap, window=window)

    # Estimate noise profile (use the first 10% of the signal as noise)
    noise_profile = np.abs(Zxx[:, :int(0.01 * Zxx.shape[1])]).mean(axis=1, keepdims=True)

    # Apply noise reduction by subtracting noise profile with a smaller factor
    magnitude = np.abs(Zxx)
    phase = np.angle(Zxx)

    # Perform noise subtraction, apply a limit to prevent artifacts
    magnitude_denoised = magnitude - noise_reduction_factor * noise_profile
    magnitude_denoised = np.maximum(magnitude_denoised, magnitude * 0.01)  # Apply a floor to avoid complete silence

    # Reconstruct the complex spectrogram (preserve phase)
    Zxx_denoised = magnitude_denoised * np.exp(1j * phase)

    # Perform inverse STFT to get back to time-domain signal
    _, reconstructed = istft(Zxx_denoised, fs=fs, nperseg=nperseg, noverlap=noverlap, window=window)

    # Convert back to AudioSegment, ensuring we scale properly
    reconstructed = np.int16(reconstructed / np.max(np.abs(reconstructed)) * 32767)  # Ensure proper scaling
    return audio_segment._spawn(reconstructed.tobytes())


f = AudioSegment.from_file("./data/audio_input/missing_queen/CJ001 - Missing Queen - Day -  (100)-6-1.wav")
n = AudioSegment.from_file("./data/noise/noise_sample.wav")
denoised = reduce_noise_stft(f, n, noise_reduction_factor=0.1)
denoised.export('./data/denoised.wav', format="wav")

# %%
def reduce_noise(audio_segment, noise_sample_path=noise_sample):
    noise_audio, noise_sr = librosa.load(noise_sample_path, sr=None)

    samples = np.array(audio_segment.get_array_of_samples()).astype(np.float32)
    if audio_segment.channels > 1:
        # If stereo, average channels to mono
        samples = samples.reshape((-1, audio_segment.channels)).mean(axis=1)

    # Reduce noise
    reduced_samples = noisereduce.reduce_noise(y=samples, y_noise=noise_audio, sr=noise_sr)

    # Convert back to AudioSegment
    reduced_chunk = AudioSegment(
        reduced_samples.tobytes(),
        frame_rate=audio_segment.frame_rate,
        sample_width=audio_segment.sample_width,
        channels=1)

    return reduced_chunk

# %%
def reduce_noise_deep_filter(audio_segment: AudioSegment, noise_reduction_factor: float = 1.0):
    # Initialize DeepFilterNet model
    model, df_state, _ = init_df()

    # Convert AudioSegment to numpy array
    samples = np.array(audio_segment.get_array_of_samples()).astype(np.float32)
    samples /= np.finfo(samples.dtype).max  # Normalize to [-1, 1]

    # Create a temporary file to store the audio
    with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as temp_file:
        temp_filename = temp_file.name
        audio_segment.export(temp_filename, format="wav")

    try:
        # Load audio using DeepFilterNet's load_audio function
        audio, _ = load_audio(temp_filename, sr=df_state.sr())

        # Enhance (denoise) the audio
        enhanced = enhance(model, df_state, audio)

        # Apply noise reduction factor
        if noise_reduction_factor != 1.0:
            enhanced = audio + noise_reduction_factor * (enhanced - audio)

        # Convert back to int16 for AudioSegment
        enhanced_int16 = np.int16(enhanced * 32767)

        # Create a new AudioSegment from the enhanced audio
        return AudioSegment(
            enhanced_int16.tobytes(),
            frame_rate=df_state.sr(),
            sample_width=2,
            channels=1
        )
    finally:
        # Clean up the temporary file
        os.unlink(temp_filename)


# Load your audio file
input_file = "./data/audio_input/missing_queen/CJ001 - Missing Queen - Day -  (100)-6-1.wav"
audio = AudioSegment.from_file(input_file)

# Apply noise reduction
denoised = reduce_noise_deep_filter(audio)

# Export the denoised audio
denoised.export('./data/denoised_deep_filter.wav', format="wav")

print("Denoising complete. Output saved as 'denoised_deep_filter.wav'")

# %%
def split_audio(input_folder, output_folder, segment_length=2000, min_amplitude_db=-30):
    input_folder_path = Path(input_folder)
    output_folder_path = Path(output_folder)

    file_counter = 0
    for file in input_folder_path.rglob('*'):
        if file.is_file() and file.suffix.lower() in {'.wav', '.mp3'}:
            file_counter += 1
            try:
                relative_path = file.relative_to(input_folder_path)

                output_subfolder = output_folder_path / relative_path.parent
                output_subfolder.mkdir(parents=True, exist_ok=True)

                audio = AudioSegment.from_file(str(file), format=file.suffix.lower()[1:])
                audio = reduce_noise_deep_filter(audio, noise_reduction_factor=0.5)

                for i, chunk in enumerate(audio[::segment_length]):
                    if chunk.dBFS > min_amplitude_db:
                        output_file = output_subfolder / f"{relative_path.parent}_{file_counter}_{i}.wav"
                        chunk.export(output_file, format=file.suffix.lower()[1:])
            except Exception as e:
                print(f"Error processing {file}: {str(e)}")
